# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # old code

# %%
import zipfile

# Specify the path to the zip file
zip_file_path = '/content/drive/MyDrive/car_project/Impersonation_attack_dataset_output.zip'

# Specify the directory where you want to extract the contents
extraction_path = '/content'

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extraction_path)

print(f"File '{zip_file_path}' has been successfully extracted.")
# Out:
# File '/content/drive/MyDrive/car_project/Impersonation_attack_dataset_output.zip' has been successfully extracted.

# %%
import os
import shutil
import random

# Define the paths to the original datasets in your Colab environment
original_dataset_paths = [
    "/content/car_project/Impersonation_attack_dataset_output",
    "/content/car_project/Attack_free_dataset_output",
    "/content/car_project/DoS_attack_dataset_output",
    "/content/car_project/Fuzzy_attack_dataset_output"
]

# Define the base path for the balanced dataset and test dataset
base_path = "/content/car_project"
if not os.path.exists(base_path):
    os.makedirs(base_path)

# Define the path for the balanced dataset (train)
balanced_dataset_path = os.path.join(base_path, "dataset_balanced")

# Define the path for the test dataset
test_dataset_path = os.path.join(base_path, "dataset_test")

# Define the minimum quantity (10,000 in your case)
min_quantity = 10000

# Define the percentage for the test dataset (30%)
test_percentage = 0.3

# Create the balanced dataset directory if it doesn't exist
if not os.path.exists(balanced_dataset_path):
    os.makedirs(balanced_dataset_path)

# Create the test dataset directory if it doesn't exist
if not os.path.exists(test_dataset_path):
    os.makedirs(test_dataset_path)

# Loop through the original datasets and create subfolders in the balanced dataset
for dataset_path in original_dataset_paths:
    # Get the class name from the dataset path
    class_name = os.path.basename(dataset_path)

    # Create a subfolder for the class in the balanced dataset
    class_folder = os.path.join(balanced_dataset_path, class_name)
    os.makedirs(class_folder, exist_ok=True)

    # Get a list of all files in the original dataset
    all_files = os.listdir(dataset_path)

    # Randomly select up to min_quantity files from the original dataset
    selected_files = random.sample(all_files, min_quantity)

    # Calculate the number of files to move to the test dataset
    num_test_files = int(len(selected_files) * test_percentage)

    # Copy the selected files to the class folder in the balanced dataset
    for file_name in selected_files:
        source_file = os.path.join(dataset_path, file_name)
        destination_file = os.path.join(class_folder, file_name)
        shutil.copy(source_file, destination_file)

    # Move a portion of the selected files to the test dataset
    test_files = selected_files[:num_test_files]
    for file_name in test_files:
        source_file = os.path.join(class_folder, file_name)
        destination_file = os.path.join(test_dataset_path, class_name, file_name)
        os.makedirs(os.path.dirname(destination_file), exist_ok=True)
        shutil.move(source_file, destination_file)

print("Balanced dataset and test dataset created successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-8925962b9793> in <cell line: 39>()
#      46
#      47     # Get a list of all files in the original dataset
# ---> 48     all_files = os.listdir(dataset_path)
#      49
#      50     # Randomly select up to min_quantity files from the original dataset
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/car_project/Impersonation_attack_dataset_output'

# %% [markdown]
# Ckeck dimensions

# %%
from PIL import Image

# Path to the folder containing the PNG files
folder_path = "/content/car_project/Attack_free_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Check if there are any PNG files in the folder
if png_files:
    # Select the first PNG file
    first_png_file = os.path.join(folder_path, png_files[0])

    # Open the image using PIL
    img = Image.open(first_png_file)

    # Get the dimensions of the image
    width, height = img.size

    # Print the dimensions
    print(f"Dimensions of the first PNG image: Width={width}, Height={height}")
else:
    print("No PNG files found in the folder.")
# Out:
# Dimensions of the first PNG image: Width=10, Height=64

# %%
cd /content
# Out:
# /content

# %%
import os

# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_balanced/Attack_free_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_balanced/DoS_attack_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_balanced/Fuzzy_attack_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_balanced/Impersonation_attack_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Out:
# Number of images in the folder: 7000
# Number of images in the folder: 7000
# Number of images in the folder: 7000
# Number of images in the folder: 13927

# %%
import os

# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_test/Attack_free_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_test/DoS_attack_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_test/Fuzzy_attack_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Path to the folder containing the PNG files
folder_path = "/content/car_project/dataset_test/Impersonation_attack_dataset_output"

# Get a list of all PNG files in the folder
png_files = [file for file in os.listdir(folder_path) if file.endswith(".png")]

# Get the count of PNG files in the folder
num_images = len(png_files)

# Print the number of images
print(f"Number of images in the folder: {num_images}")
# Out:
# Number of images in the folder: 3000
# Number of images in the folder: 3000
# Number of images in the folder: 3000
# Number of images in the folder: 5993

# %%
import os
import hashlib

# Define the paths to the balanced and test datasets
balanced_dataset_path = "/content/car_project/dataset_balanced/Impersonation_attack_dataset_output"
test_dataset_path = "/content/car_project/dataset_test/Impersonation_attack_dataset_output"

# Function to calculate the hash of a file
def file_hash(filepath):
    hasher = hashlib.md5()
    with open(filepath, 'rb') as f:
        while True:
            data = f.read(8192)  # Read the file in 8KB chunks
            if not data:
                break
            hasher.update(data)
    return hasher.hexdigest()

# Create a dictionary to store file hashes and their paths
file_hashes = {}

# Function to find and delete excess duplicate files
def delete_excess_duplicates(directory, max_duplicates):
    for root, _, files in os.walk(directory):
        for filename in files:
            file_path = os.path.join(root, filename)
            file_hash_value = file_hash(file_path)
            if file_hash_value in file_hashes:
                # This file is a duplicate
                file_hashes[file_hash_value].append(file_path)
            else:
                file_hashes[file_hash_value] = [file_path]

    # Check for and delete excess duplicates
    for hash_value, paths in file_hashes.items():
        if len(paths) > max_duplicates:
            # Sort the paths by file modification time (keep the most recent)
            paths.sort(key=lambda x: os.path.getmtime(x), reverse=True)
            for path in paths[max_duplicates:]:
                os.remove(path)
                print(f"Deleted excess duplicate: {path}")

# Set the maximum allowed duplicates (7k for balanced, 3k for test)
max_duplicates_balanced = 7000
max_duplicates_test = 3000

# Delete excess duplicates in the balanced dataset
delete_excess_duplicates(balanced_dataset_path, max_duplicates_balanced)

# Delete excess duplicates in the test dataset
delete_excess_duplicates(test_dataset_path, max_duplicates_test)

# %% [markdown]
# # copying data from drive after code loss

# %%
# !cp -r /content/drive/MyDrive/car_project/car_project /content

# %% [markdown]
# # code to train CNN

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models

# Function to load images from a folder and return images and labels
def load_images_from_folder(folder):
    images = []
    labels = []
    class_folders = os.listdir(folder)

    for label, class_folder in enumerate(class_folders):
        label_folder = os.path.join(folder, class_folder)
        if os.path.isdir(label_folder):
            for filename in os.listdir(label_folder):
                img_path = os.path.join(label_folder, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    images.append(img)
                    labels.append(label)
    return np.array(images), np.array(labels)

# Define your train and test folder paths
train_folder = '/content/car_project/dataset_balanced'
test_folder = '/content/car_project/dataset_test'

# Load images and labels from folders
X_train, y_train = load_images_from_folder(train_folder)
X_test, y_test = load_images_from_folder(test_folder)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=0)

# Normalize pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Reshape the images for the CNN (add channel dimension)
X_train = X_train.reshape(-1, 10, 64, 1)
X_val = X_val.reshape(-1, 10, 64, 1)
X_test = X_test.reshape(-1, 10, 64, 1)

# Define the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))  # Adjust output units based on your number of classes

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history (optional)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Generate a classification report and confusion matrix (optional)
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Epoch 1/10
# 788/788 [==============================] - 16s 19ms/step - loss: 0.5935 - accuracy: 0.7375 - val_loss: 0.4483 - val_accuracy: 0.7936
# Epoch 2/10
# 788/788 [==============================] - 12s 15ms/step - loss: 0.4220 - accuracy: 0.8116 - val_loss: 0.4214 - val_accuracy: 0.8089
# Epoch 3/10
# 788/788 [==============================] - 12s 15ms/step - loss: 0.3642 - accuracy: 0.8379 - val_loss: 0.3675 - val_accuracy: 0.8275
# Epoch 4/10
# 788/788 [==============================] - 10s 13ms/step - loss: 0.3262 - accuracy: 0.8520 - val_loss: 0.3448 - val_accuracy: 0.8461
# Epoch 5/10
# 788/788 [==============================] - 12s 15ms/step - loss: 0.3014 - accuracy: 0.8644 - val_loss: 0.3367 - val_accuracy: 0.8464
# Epoch 6/10
# 788/788 [==============================] - 12s 15ms/step - loss: 0.2762 - accuracy: 0.8755 - val_loss: 0.3103 - val_accuracy: 0.8696
# Epoch 7/10
# ...

# %% [markdown]
# ##re-try with different architecture

# %%
model.save("CNN1.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models

# Function to load images from a folder and return images and labels
def load_images_from_folder(folder):
    images = []
    labels = []
    class_folders = os.listdir(folder)

    for label, class_folder in enumerate(class_folders):
        label_folder = os.path.join(folder, class_folder)
        if os.path.isdir(label_folder):
            for filename in os.listdir(label_folder):
                img_path = os.path.join(label_folder, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    images.append(img)
                    labels.append(label)
    return np.array(images), np.array(labels)

# Define your train and test folder paths
train_folder = '/content/car_project/dataset_balanced'
test_folder = '/content/car_project/dataset_test'

# Load images and labels from folders
X_train, y_train = load_images_from_folder(train_folder)
X_test, y_test = load_images_from_folder(test_folder)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=0)

# Normalize pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Reshape the images for the CNN (add channel dimension)
X_train = X_train.reshape(-1, 10, 64, 1)
X_val = X_val.reshape(-1, 10, 64, 1)
X_test = X_test.reshape(-1, 10, 64, 1)

# Define the CNN model with improvements
model = models.Sequential()
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(10, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))  # Adjust output units based on your number of classes

# Implement learning rate scheduling
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=1000,
    decay_rate=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# Compile the model
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history (optional)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Generate a classification report and confusion matrix (optional)
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Epoch 1/10
# 788/788 [==============================] - 32s 39ms/step - loss: 0.6541 - accuracy: 0.6989 - val_loss: 0.4740 - val_accuracy: 0.7825
# Epoch 2/10
# 788/788 [==============================] - 30s 38ms/step - loss: 0.4284 - accuracy: 0.7995 - val_loss: 0.3759 - val_accuracy: 0.8314
# Epoch 3/10
# 788/788 [==============================] - 31s 39ms/step - loss: 0.3511 - accuracy: 0.8357 - val_loss: 0.3479 - val_accuracy: 0.8350
# Epoch 4/10
# 788/788 [==============================] - 33s 42ms/step - loss: 0.3104 - accuracy: 0.8563 - val_loss: 0.3023 - val_accuracy: 0.8532
# Epoch 5/10
# 788/788 [==============================] - 30s 38ms/step - loss: 0.2784 - accuracy: 0.8687 - val_loss: 0.2890 - val_accuracy: 0.8632
# Epoch 6/10
# 788/788 [==============================] - 30s 38ms/step - loss: 0.2559 - accuracy: 0.8821 - val_loss: 0.2624 - val_accuracy: 0.8789
# Epoch 7/10
# ...

# %%
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 788/788 [==============================] - 32s 40ms/step - loss: 0.1796 - accuracy: 0.9187 - val_loss: 0.2421 - val_accuracy: 0.8950
# Epoch 2/20
# 788/788 [==============================] - 30s 38ms/step - loss: 0.1712 - accuracy: 0.9220 - val_loss: 0.2317 - val_accuracy: 0.9007
# Epoch 3/20
# 788/788 [==============================] - 31s 39ms/step - loss: 0.1607 - accuracy: 0.9286 - val_loss: 0.2346 - val_accuracy: 0.8989
# Epoch 4/20
# 788/788 [==============================] - 31s 40ms/step - loss: 0.1533 - accuracy: 0.9332 - val_loss: 0.2384 - val_accuracy: 0.9021
# Epoch 5/20
# 788/788 [==============================] - 30s 38ms/step - loss: 0.1459 - accuracy: 0.9362 - val_loss: 0.2388 - val_accuracy: 0.9054
# Epoch 6/20
# 788/788 [==============================] - 31s 40ms/step - loss: 0.1382 - accuracy: 0.9405 - val_loss: 0.2395 - val_accuracy: 0.9071
# Epoch 7/20
# ...

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history (optional)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Generate a classification report and confusion matrix (optional)
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
# Out:
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2841 - accuracy: 0.8997
# Test accuracy: 0.8996666669845581
# 375/375 [==============================] - 4s 11ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87      3000
#            1       0.86      0.84      0.85      3000
#            2       0.88      0.89      0.88      3000
#            3       1.00      1.00      1.00      3000
#
#     accuracy                           0.90     12000
#    macro avg       0.90      0.90      0.90     12000
# weighted avg       0.90      0.90      0.90     12000
#
# Confusion Matrix:

# %% [markdown]
# #means  during this approach, max we can learn is about 99%

# %% [markdown]
# # Approach 2 (increasing the dataset size)

# %%
import zipfile

# Specify the path to the zip file
zip_file_path = '/content/drive/MyDrive/car_project/Impersonation_attack_dataset_output.zip'

# Specify the directory where you want to extract the contents
extraction_path = '/content/approach2'

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extraction_path)

print(f"File '{zip_file_path}' has been successfully extracted.")
# Out:
# File '/content/drive/MyDrive/car_project/Impersonation_attack_dataset_output.zip' has been successfully extracted.

# %%
import os
import shutil
import random

# Define the paths to the original datasets in your Colab environment
original_dataset_paths = [
    "/content/approach2/Impersonation_attack_dataset_output",
    "/content/approach2/Attack_free_dataset_output",
    "/content/approach2/DoS_attack_dataset_output",
    "/content/approach2/Fuzzy_attack_dataset_output"
]

# Define the base path for the balanced dataset and test dataset
base_path = "/content/approach2/car_project"
if not os.path.exists(base_path):
    os.makedirs(base_path)

# Define the path for the balanced dataset (train)
balanced_dataset_path = os.path.join(base_path, "dataset_balanced")

# Define the path for the test dataset
test_dataset_path = os.path.join(base_path, "dataset_test")

# Define the minimum quantity (10,000 in your case)
min_quantity = 30000

# Define the percentage for the test dataset (30%)
test_percentage = 0.3

# Create the balanced dataset directory if it doesn't exist
if not os.path.exists(balanced_dataset_path):
    os.makedirs(balanced_dataset_path)

# Create the test dataset directory if it doesn't exist
if not os.path.exists(test_dataset_path):
    os.makedirs(test_dataset_path)

# Loop through the original datasets and create subfolders in the balanced dataset
for dataset_path in original_dataset_paths:
    # Get the class name from the dataset path
    class_name = os.path.basename(dataset_path)

    # Create a subfolder for the class in the balanced dataset
    class_folder = os.path.join(balanced_dataset_path, class_name)
    os.makedirs(class_folder, exist_ok=True)

    # Get a list of all files in the original dataset
    all_files = os.listdir(dataset_path)

    # Randomly select up to min_quantity files from the original dataset
    selected_files = random.sample(all_files, min_quantity)

    # Calculate the number of files to move to the test dataset
    num_test_files = int(len(selected_files) * test_percentage)

    # Copy the selected files to the class folder in the balanced dataset
    for file_name in selected_files:
        source_file = os.path.join(dataset_path, file_name)
        destination_file = os.path.join(class_folder, file_name)
        shutil.copy(source_file, destination_file)

    # Move a portion of the selected files to the test dataset
    test_files = selected_files[:num_test_files]
    for file_name in test_files:
        source_file = os.path.join(class_folder, file_name)
        destination_file = os.path.join(test_dataset_path, class_name, file_name)
        os.makedirs(os.path.dirname(destination_file), exist_ok=True)
        shutil.move(source_file, destination_file)

print("Balanced dataset and test dataset created successfully.")
# Out:
# Balanced dataset and test dataset created successfully.

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models

# Function to load images from a folder and return images and labels
def load_images_from_folder(folder):
    images = []
    labels = []
    class_folders = os.listdir(folder)

    for label, class_folder in enumerate(class_folders):
        label_folder = os.path.join(folder, class_folder)
        if os.path.isdir(label_folder):
            for filename in os.listdir(label_folder):
                img_path = os.path.join(label_folder, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    images.append(img)
                    labels.append(label)
    return np.array(images), np.array(labels)

# Define your train and test folder paths
train_folder = '/content/approach2/car_project/dataset_balanced'
test_folder = '/content/approach2/car_project/dataset_test'

# Load images and labels from folders
X_train, y_train = load_images_from_folder(train_folder)
X_test, y_test = load_images_from_folder(test_folder)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=0)

# Normalize pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Reshape the images for the CNN (add channel dimension)
X_train = X_train.reshape(-1, 10, 64, 1)
X_val = X_val.reshape(-1, 10, 64, 1)
X_test = X_test.reshape(-1, 10, 64, 1)

# Define the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))  # Adjust output units based on your number of classes

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history (optional)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Generate a classification report and confusion matrix (optional)
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Epoch 1/10
# 2363/2363 [==============================] - 49s 20ms/step - loss: 0.4761 - accuracy: 0.7854 - val_loss: 0.3942 - val_accuracy: 0.8145
# Epoch 2/10
# 2363/2363 [==============================] - 45s 19ms/step - loss: 0.3151 - accuracy: 0.8558 - val_loss: 0.2916 - val_accuracy: 0.8638
# Epoch 3/10
# 2363/2363 [==============================] - 40s 17ms/step - loss: 0.2602 - accuracy: 0.8813 - val_loss: 0.2504 - val_accuracy: 0.8852
# Epoch 4/10
# 2363/2363 [==============================] - 44s 19ms/step - loss: 0.2289 - accuracy: 0.8946 - val_loss: 0.2333 - val_accuracy: 0.8879
# Epoch 5/10
# 2363/2363 [==============================] - 43s 18ms/step - loss: 0.2100 - accuracy: 0.9029 - val_loss: 0.2311 - val_accuracy: 0.8927
# Epoch 6/10
# 2363/2363 [==============================] - 38s 16ms/step - loss: 0.1940 - accuracy: 0.9101 - val_loss: 0.2169 - val_accuracy: 0.8964
# Epoch 7/10
# ...

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history (optional)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Generate a classification report and confusion matrix (optional)
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Epoch 1/10
# 2363/2363 [==============================] - 48s 20ms/step - loss: 0.1456 - accuracy: 0.9339 - val_loss: 0.2233 - val_accuracy: 0.9025
# Epoch 2/10
# 2363/2363 [==============================] - 47s 20ms/step - loss: 0.1392 - accuracy: 0.9372 - val_loss: 0.1992 - val_accuracy: 0.9107
# Epoch 3/10
# 2363/2363 [==============================] - 48s 20ms/step - loss: 0.1329 - accuracy: 0.9399 - val_loss: 0.2057 - val_accuracy: 0.9120
# Epoch 4/10
# 2363/2363 [==============================] - 41s 17ms/step - loss: 0.1264 - accuracy: 0.9430 - val_loss: 0.2098 - val_accuracy: 0.9094
# Epoch 5/10
# 2363/2363 [==============================] - 45s 19ms/step - loss: 0.1214 - accuracy: 0.9466 - val_loss: 0.2015 - val_accuracy: 0.9133
# Epoch 6/10
# 2363/2363 [==============================] - 39s 17ms/step - loss: 0.1165 - accuracy: 0.9476 - val_loss: 0.2021 - val_accuracy: 0.9157
# Epoch 7/10
# ...

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras import layers, models

# Function to load images from a folder and return images and labels
def load_images_from_folder(folder):
    images = []
    labels = []
    class_folders = os.listdir(folder)

    for label, class_folder in enumerate(class_folders):
        label_folder = os.path.join(folder, class_folder)
        if os.path.isdir(label_folder):
            for filename in os.listdir(label_folder):
                img_path = os.path.join(label_folder, filename)
                img = cv2.imread(img_path, cv2.IMREAD_COLOR)
                if img is not None:
                    img = cv2.resize(img, (224, 224))  # Resize images to match VGG19 input size
                    images.append(img)
                    labels.append(label)
    return np.array(images), np.array(labels)

# Define your train and test folder paths
train_folder = '/content/car_project/dataset_balanced'
test_folder = '/content/car_project/dataset_test'

# Load images and labels from folders
X_train, y_train = load_images_from_folder(train_folder)
X_test, y_test = load_images_from_folder(test_folder)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=0)

# Normalize pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Use VGG19 as the base model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create a custom top classifier for your specific task
top_model = models.Sequential()
top_model.add(layers.Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(layers.Dense(256, activation='relu'))
top_model.add(layers.Dropout(0.5))
top_model.add(layers.Dense(4, activation='softmax'))  # Adjust output units based on your number of classes

# Combine the base model and top classifier
model = models.Model(inputs=base_model.input, outputs=top_model(base_model.output))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history (optional)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Generate a classification report and confusion matrix (optional)
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
